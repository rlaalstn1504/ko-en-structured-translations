# %%
import csv
import json
import time
import re
from datetime import datetime
from pathlib import Path

import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
MODEL_NAME = "gpt-4o-mini"
TEMPERATURE = 0.9
TOP_P = 0.95
MAX_TOKENS = 2000

NUM_PAIRS_PER_COMBO = 20     # 한 조합당 생성할 문장 쌍 수
MAX_RETRIES = 3              # LLM 호출 재시도 횟수
SLEEP_BETWEEN_CALLS = 0.2    # 호출 사이 간격(초)
PROMPT_VERSION = "v2_structured"

OUTPUT_DIR = Path("data")
OUTPUT_DIR.mkdir(exist_ok=True)
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

csv_path = OUTPUT_DIR / f"parallel_data_{MODEL_NAME}_{PROMPT_VERSION}_{timestamp}.csv"

# %%
# 1. LLM 인스턴스 생성
llm = ChatOpenAI(
    model=MODEL_NAME,
    temperature=TEMPERATURE,
    top_p=TOP_P,
    max_tokens=MAX_TOKENS,
)

# 2. 주제 / 스타일 / 문장 타입 목록
topics = [
    "여행", "일상생활", "건강", "식당", "기술", "업무", "교육", "시간관리",
    "감정표현", "경제/금융", "스포츠", "기후/날씨", "교통", "고객센터",
    "문화/예술", "쇼핑", "직장 관계", "IT/AI", "자기계발", "사회/뉴스",
]

styles = [
    "대화체",
    "문어체(보고서 스타일)",
    "SNS 스타일",
    "뉴스 기사체",
    "기술 설명체",
    "감정 표현 스타일",
    "조언/상담 스타일",
    "고객센터 안내 스타일",
]

types = [
    "단문",
    "복문",
    "조건문",
    "비교문",
    "원인·결과문",
    "명령/요청문",
]

# 3. JSON 구조화 출력 프롬프트
prompt_template = ChatPromptTemplate.from_template(
    """
너는 한국어-영어 번역 데이터셋을 만드는 어시스턴트야.

주제: {topic}
문체 스타일: {style}
문장 구조 타입: {type}
생성할 문장 쌍 수: {num_pairs}

조건:
- 반드시 한국어-영어 병렬 문장 {num_pairs}쌍을 생성할 것
- 각 문장은 서로 다른 구조와 길이, 표현을 사용할 것
- 한국어와 영어는 의미적으로 정확히 대응할 것
- 직역투를 피하고 자연스러운 표현을 사용할 것
- 한국어 문장 길이는 대략 10~40자, 영어 문장 길이는 대략 10~80자 정도로 할 것
- 중복 표현을 피할 것
- 반말, 존댓말(해요체), 격식체(합니다체)를 전체 데이터셋에서 골고루 섞어서 사용하되,
  각 문장 안에서는 말투를 일관되게 유지할 것

출력 형식(중요):
- 반드시 아래 JSON 형식의 "하나의 객체"만 출력해
- JSON 이외의 설명, 마크다운, 코드블록, 주석, 텍스트를 절대 추가하지 마

출력 예시 형식(구조만 참고):

- "pairs" 키 아래에 한국어-영어 문장 쌍 리스트를 둔다고 생각하고 작성해.
규칙:
- key 이름은 반드시 "pairs", "ko", "en"만 사용해
- "pairs"는 길이가 {num_pairs}인 리스트여야 해
- JSON 문법 오류가 없도록 유효한 JSON만 출력해
    """
)

# 4. LLM 출력 파싱 함수 (한 호출 결과 → (ko, en) 리스트)
def parse_output(response):
    text = getattr(response, "content", str(response))
    try:
        data = json.loads(text)
    except json.JSONDecodeError as e:
        print("[JSON 파싱 실패]", e)
        return []

    raw_pairs = data.get("pairs", [])
    cleaned_pairs = []
    for item in raw_pairs:
        ko = str(item.get("ko", "")).strip()
        en = str(item.get("en", "")).strip()
        if not ko or not en:
            continue

        # 길이 필터링
        if not (10 <= len(ko) <= 80):
            continue
        if not (10 <= len(en) <= 120):
            continue

        cleaned_pairs.append((ko, en))

    return cleaned_pairs

# 5. 체인 정의 (프롬프트 → LLM → 파싱)
chain = prompt_template | llm | RunnableLambda(parse_output)

# 6. 전체 조합 입력 만들기
combos = [
    {"topic": t, "style": s, "type": ty, "num_pairs": NUM_PAIRS_PER_COMBO}
    for t in topics
    for s in styles
    for ty in types
]
total_combos = len(combos)
print(f"총 조합 수: {total_combos} (topic x style x type)")

# 7. 병렬(batch) 호출
#    max_concurrency 값을 4~16 사이에서 조절해 보세요.
MAX_CONCURRENCY = 8
results = chain.batch(combos, {"max_concurrency": MAX_CONCURRENCY})

# 8. 결과 모으기
rows = []
seen_pairs = set()

for idx, (combo, pairs) in enumerate(zip(combos, results), start=1):
    topic = combo["topic"]
    style = combo["style"]
    type_ = combo["type"]

    unique_pairs = []
    for ko, en in pairs:
        key = (ko, en)
        if key in seen_pairs:
            continue
        seen_pairs.add(key)
        unique_pairs.append((ko, en))

    for ko, en in unique_pairs:
        rows.append(
            {
                "id": len(rows) + 1,
                "topic": topic,
                "style": style,
                "type": type_,
                "ko": ko,
                "en": en,
                "model": MODEL_NAME,
                "prompt_version": PROMPT_VERSION,
                "created_at": timestamp,
            }
        )

    print(
        f"[생성 완료] [{idx}/{total_combos}] {topic} / {style} / {type_} → "
        f"{len(unique_pairs)}쌍 추가 (누적 {len(rows)}쌍)"
    )

# 9. CSV 저장 + train/valid/test 분할
if not rows:
    print("[경고] 생성된 데이터가 없습니다.")
else:
    df = pd.DataFrame(rows)
    df = df.sample(frac=1.0, random_state=42).reset_index(drop=True)

    train_ratio = 0.8
    valid_ratio = 0.1  # 나머지 0.1은 test

    n = len(df)
    train_end = int(n * train_ratio)
    valid_end = int(n * (train_ratio + valid_ratio))

    df["split"] = "train"
    df.loc[train_end:valid_end, "split"] = "valid"
    df.loc[valid_end:, "split"] = "test"

    df.to_csv(csv_path, index=False, encoding="utf-8")

    train_path = csv_path.with_name("train.csv")
    valid_path = csv_path.with_name("valid.csv")
    test_path = csv_path.with_name("test.csv")

    df[df["split"] == "train"].to_csv(train_path, index=False, encoding="utf-8")
    df[df["split"] == "valid"].to_csv(valid_path, index=False, encoding="utf-8")
    df[df["split"] == "test"].to_csv(test_path, index=False, encoding="utf-8")

    print(f"\n[저장 완료] 전체: {csv_path}")
    print(f"[저장 완료] train: {train_path}")
    print(f"[저장 완료] valid: {valid_path}")
    print(f"[저장 완료] test:  {test_path}")
# Out:
# 총 조합 수: 960 (topic x style x type)
# [생성 완료] [1/960] 여행 / 대화체 / 단문 → 9쌍 추가 (누적 9쌍)
# [생성 완료] [2/960] 여행 / 대화체 / 복문 → 10쌍 추가 (누적 19쌍)
# [생성 완료] [3/960] 여행 / 대화체 / 조건문 → 10쌍 추가 (누적 29쌍)
# [생성 완료] [4/960] 여행 / 대화체 / 비교문 → 10쌍 추가 (누적 39쌍)
# [생성 완료] [5/960] 여행 / 대화체 / 원인·결과문 → 10쌍 추가 (누적
/ 문어체(보고서 스타일) / 단문 → 10쌍 추가 (누적 3398쌍)
# [생성 완료] [344/960] 시간관리 / 문어체(보고서 스타일) / 복문 → 10쌍 추가 (누적 3408쌍)
# [생성 완료] [345/960] 시간관리 / 문어체(보고서 스타일) / 조건문 → 10쌍 추가 (누적 3418쌍)
# [생성 완료] [346/960] 시간관리 / 문어체(보고서 스타일) / 비교문 → 10쌍 추가 (누적 3428쌍)
# [생성 완료] [347/960] 시간관리 / 문어체(보고서 스타일) / 원인·결과문 → 10쌍 추가 (누적 3438쌍)
# [생성 완료] [348/960] 시간관리 / 문어체(보고서 스타일) / 명령/요청문 → 10쌍 추가 (누적 3448쌍)
# [생성 완료] [349/960] 시간관리 / SNS 스타일 / 단문 → 9쌍 추가 (누적 3457쌍)
# [생성 완료] [350/960] 시간관리 / SNS 스타일 / 복문 → 10쌍 추가 (누적 3467쌍)
# [생성 완료] [351/960] 시간관리 / SNS 스타일 / 조건문 → 10쌍 추가 (누적 3477쌍)
# [생성 완료] [352/960] 시간관리 / SNS 스타일 / 비교문 → 10쌍 추가 (누적 3487쌍)
# [생성 완료] [353/960] 시간관리 / SNS 스타일 / 원인·결과문 → 9쌍 추가 (누적 3496쌍)
# [생성 완료] [354/960] 시간관리 / SNS 스타일 / 명령/요청문 → 10쌍 추가 (누적 3506쌍)
# [생성 완료] [355/960] 시간관리 / 뉴스 기사체 / 단문 → 10쌍 추가 (누적 3516쌍)
# [생성 완료] [356/960] 시간관리 / 뉴스 기사체 / 복문 → 10쌍 추가 (누적 3526쌍)
# [생성 완료] [357/960] 시간관리 / 뉴스 기사체 / 조건문 → 10쌍 추가 (누적 3536쌍)
# [생성 완료] [358/960] 시간관리 / 뉴스 기사체 / 비교문 → 9쌍 추가 (누적 3545쌍)
# [생성 완료] [359/960] 시간관리 / 뉴스 기사체 / 원인·결과문 → 10쌍 추가 (누적 3555쌍)
# [생성 완료] [360/960] 시간관리 / 뉴스 기사체 / 명령/요청문 → 10쌍 추가 (누적 3565쌍)
# [생성 완료] [361/960] 시간관리 / 기술 설명체 / 단문 → 10쌍 추가 (누적 3575쌍)
# [생성 완료] [362/960] 시간관리 / 기술 설명체 / 복문 → 10쌍 추가 (누적 3585쌍)
# [생성 완료] [363/960] 시간관리 / 기술 설명체 / 조건문 → 9쌍 추가 (누적 3594쌍)
# [생성 완료] [364/960] 시간관리 / 기술 설명체 / 비교문 → 10쌍 추가 (누적 3604쌍)
# [생성 완료] [365/960] 시간관리 / 기술 설명체 / 원인·결과문 → 10쌍 추가 (누적 3614쌍)
# [생성 완료] [366/960] 시간관리 / 기술 설명체 / 명령/요청문 → 9쌍 추가 (누적 3623쌍)
# [생성 완료] [367/960] 시간관리 / 감정 표현 스타일 / 단문 → 10쌍 추가 (누적 3633쌍)
# [생성 완료] [368/960] 시간관리 / 감정 표현 스타일 / 복문 → 10쌍 추가 (누적 3643쌍)
# [생성 완료] [369/960] 시간관리 / 감정 표현 스타일 / 조건문 → 9쌍 추가 (누적 3652쌍)
# [생성 완료] [370/960] 시간관리 / 감정 표현 스타일 / 비교문 → 10쌍 추가 (누적 3662쌍)
# [생성 완료] [371/960] 시간관리 / 감정 표현 스타일 / 원인·결과문 → 10쌍 추가 (누적 3672쌍)
# [생성 완료] [372/960] 시간관리 / 감정 표현 스타일 / 명령/요청문 → 10쌍 추가 (누적 3682쌍)
# [생성 완료] [373/960] 시간관리 / 조언/상담 스타일 / 단문 → 8쌍 추가 (누적 3690쌍)
# [생성 완료] [374/960] 시간관리 / 조언/상담 스타일 / 복문 → 10쌍 추가 (누적 3700쌍)
# [생성 완료] [375/960] 시간관리 / 조언/상담 스타일 / 조건문 → 10쌍 추가 (누적 3710쌍)
# [생성 완료] [376/960] 시간관리 / 조언/상담 스타일 / 비교문 → 10쌍 추가 (누적 3720쌍)
# [생성 완료] [377/960] 시간관리 / 조언/상담 스타일 / 원인·결과문 → 9쌍 추가 (누적 3729쌍)
# [생성 완료] [378/960] 시간관리 / 조언/상담 스타일 / 명령/요청문 → 10쌍 추가 (누적 3739쌍)
# [생성 완료] [379/960] 시간관리 / 고객센터 안내 스타일 / 단문 → 10쌍 추가 (누적 3749쌍)
# [생성 완료] [380/960] 시간관리 / 고객센터 안내 스타일 / 복문 → 10쌍 추가 (누적 3759쌍)
# [생성 완료] [381/960] 시간관리 / 고객센터 안내 스타일 / 조건문 → 10쌍 추가 (누적 3769쌍)
# [생성 완료] [382/960] 시간관리 / 고객센터 안내 스타일 / 비교문 → 9쌍 추가 (누적 3778쌍)
# [생성 완료] [383/960] 시간관리 / 고객센터 안내 스타일 / 원인·결과문 → 10쌍 추가 (누적 3788쌍)
# [생성 완료] [384/960] 시간관리 / 고객센터 안내 스타일 / 명령/요청문 → 10쌍 추가 (누적 3798쌍)
# [생성 완료] [385/960] 감정표현 / 대화체 / 단문 → 8쌍 추가 (누적 3806쌍)
# [생성 완료] [386/960] 감정표현 / 대화체 / 복문 → 10쌍 추가 (누적 3816쌍)
# [생성 완료] [387/960] 감정표현 / 대화체 / 조건문 → 10쌍 추가 (누적 3826쌍)
# [생성 완료] [388/960] 감정표현 / 대화체 / 비교문 → 10쌍 추가 (누적 3836쌍)
# [생성 완료] [389/960] 감정표현 / 대화체 / 원인·결과문 → 10쌍 추가 (누적 3846쌍)
# [생성 완료] [390/960] 감정표현 / 대화체 / 명령/요청문 → 8쌍 추가 (누적 3854쌍)
# [생성 완료] [391/960] 감정표현 / 문어체(보고서 스타일) / 단문 → 7쌍 추가 (누적 3861쌍)
# [생성 완료] [392/960] 감정표현 / 문어체(보고서 스타일) / 복문 → 10쌍 추가 (누적 3871쌍)
# [생성 완료] [393/960] 감정표현 / 문어체(보고서 스타일) / 조건문 → 10쌍 추가 (누적 3881쌍)
# [생성 완료] [394/960] 감정표현 / 문어체(보고서 스타일) / 비교문 → 10쌍 추가 (누적 3891쌍)
# [생성 완료] [395/960] 감정표현 / 문어체(보고서 스타일) / 원인·결과문 → 10쌍 추가 (누적 3901쌍)
# [생성 완료] [396/960] 감정표현 / 문어체(보고서 스타일) / 명령/요청문 → 10쌍 추가 (누적 3911쌍)
# [생성 완료] [397/960] 감정표현 / SNS 스타일 / 단문 → 8쌍 추가 (누적 3919쌍)
# [생성 완료] [398/960] 감정표현 / SNS 스타일 / 복문 → 10쌍 추가 (누적 3929쌍)
# [생성 완료] [399/960] 감정표현 / SNS 스타일 / 조건문 → 10쌍 추가 (누적 3939쌍)
# [생성 완료] [400/960] 감정표현 / SNS 스타일 / 비교문 → 10쌍 추가 (누적 3949쌍)
# [생성 완료] [401/960] 감정표현 / SNS 스타일 / 원인·결과문 → 10쌍 추가 (누적 3959쌍)
# [생성 완료] [402/960] 감정표현 / SNS 스타일 / 명령/요청문 → 10쌍 추가 (누적 3969쌍)
# [생성 완료] [403/960] 감정표현 / 뉴스 기사체 / 단문 → 10쌍 추가 (누적 3979쌍)
# [생성 완료] [404/960] 감정표현 / 뉴스 기사체 / 복문 → 10쌍 추가 (누적 3989쌍)
# [생성 완료] [405/960] 감정표현 / 뉴스 기사체 / 조건문 → 10쌍 추가 (누적 3999쌍)
# [생성 완료] [406/960] 감정표현 / 뉴스 기사체 / 비교문 → 10쌍 추가 (누적 4009쌍)
# [생성 완료] [407/960] 감정표현 / 뉴스 기사체 / 원인·결과문 → 10쌍 추가 (누적 4019쌍)
# [생성 완료] [408/960] 감정표현 / 뉴스 기사체 / 명령/요청문 → 10쌍 추가 (누적 4029쌍)
# [생성 완료] [409/960] 감정표현 / 기술 설명체 / 단문 → 7쌍 추가 (누적 4036쌍)
# [생성 완료] [410/960] 감정표현 / 기술 설명체 / 복문 → 10쌍 추가 (누적 4046쌍)
# [생성 완료] [411/960] 감정표현 / 기술 설명체 / 조건문 → 10쌍 추가 (누적 4056쌍)
# [생성 완료] [412/960] 감정표현 / 기술 설명체 / 비교문 → 10쌍 추가 (누적 4066쌍)
# [생성 완료] [413/960] 감정표현 / 기술 설명체 / 원인·결과문 → 10쌍 추가 (누적 4076쌍)
# [생성 완료] [414/960] 감정표현 / 기술 설명체 / 명령/요청문 → 8쌍 추가 (누적 4084쌍)
# [생성 완료] [415/960] 감정표현 / 감정 표현 스타일 / 단문 → 10쌍 추가 (누적 4094쌍)
# [생성 완료] [416/960] 감정표현 / 감정 표현 스타일 / 복문 → 10쌍 추가 (누적 4104쌍)
# [생성 완료] [417/960] 감정표현 / 감정 표현 스타일 / 조건문 → 10쌍 추가 (누적 4114쌍)
# [생성 완료] [418/960] 감정표현 / 감정 표현 스타일 / 비교문 → 10쌍 추가 (누적 4124쌍)
# [생성 완료] [419/960] 감정표현 / 감정 표현 스타일 / 원인·결과문 → 10쌍 추가 (누적 4134쌍)
# [생성 완료] [420/960] 감정표현 / 감정 표현 스타일 / 명령/요청문 → 10쌍 추가 (누적 4144쌍)
# [생성 완료] [421/960] 감정표현 / 조언/상담 스타일 / 단문 → 10쌍 추가 (누적 4154쌍)
# [생성 완료] [422/960] 감정표현 / 조언/상담 스타일 / 복문 → 10쌍 추가 (누적 4164쌍)
# [생성 완료] [423/960] 감정표현 / 조언/상담 스타일 / 조건문 → 10쌍 추가 (누적 4174쌍)
# [생성 완료] [424/960] 감정표현 / 조언/상담 스타일 / 비교문 → 10쌍 추가 (누적 4184쌍)
# [생성 완료] [425/960] 감정표현 / 조언/상담 스타일 / 원인·결과문 → 10쌍 추가 (누적 4194쌍)
# [생성 완료] [426/960] 감정표현 / 조언/상담 스타일 / 명령/요청문 → 10쌍 추가 (누적
/ SNS 스타일 / 원인·결과문 → 10쌍 추가 (누적 7760쌍)
# [생성 완료] [786/960] 직장 관계 / SNS 스타일 / 명령/요청문 → 9쌍 추가 (누적 7769쌍)
# [생성 완료] [787/960] 직장 관계 / 뉴스 기사체 / 단문 → 10쌍 추가 (누적 7779쌍)
# [생성 완료] [788/960] 직장 관계 / 뉴스 기사체 / 복문 → 10쌍 추가 (누적 7789쌍)
# [생성 완료] [789/960] 직장 관계 / 뉴스 기사체 / 조건문 → 10쌍 추가 (누적 7799쌍)
# [생성 완료] [790/960] 직장 관계 / 뉴스 기사체 / 비교문 → 10쌍 추가 (누적 7809쌍)
# [생성 완료] [791/960] 직장 관계 / 뉴스 기사체 / 원인·결과문 → 10쌍 추가 (누적 7819쌍)
# [생성 완료] [792/960] 직장 관계 / 뉴스 기사체 / 명령/요청문 → 10쌍 추가 (누적 7829쌍)
# [생성 완료] [793/960] 직장 관계 / 기술 설명체 / 단문 → 10쌍 추가 (누적 7839쌍)
# [생성 완료] [794/960] 직장 관계 / 기술 설명체 / 복문 → 10쌍 추가 (누적 7849쌍)
# [생성 완료] [795/960] 직장 관계 / 기술 설명체 / 조건문 → 10쌍 추가 (누적 7859쌍)
# [생성 완료] [796/960] 직장 관계 / 기술 설명체 / 비교문 → 10쌍 추가 (누적 7869쌍)
# [생성 완료] [797/960] 직장 관계 / 기술 설명체 / 원인·결과문 → 10쌍 추가 (누적 7879쌍)
# [생성 완료] [798/960] 직장 관계 / 기술 설명체 / 명령/요청문 → 10쌍 추가 (누적 7889쌍)
# [생성 완료] [799/960] 직장 관계 / 감정 표현 스타일 / 단문 → 9쌍 추가 (누적 7898쌍)
# [생성 완료] [800/960] 직장 관계 / 감정 표현 스타일 / 복문 → 10쌍 추가 (누적 7908쌍)
# [생성 완료] [801/960] 직장 관계 / 감정 표현 스타일 / 조건문 → 10쌍 추가 (누적 7918쌍)
# [생성 완료] [802/960] 직장 관계 / 감정 표현 스타일 / 비교문 → 10쌍 추가 (누적 7928쌍)
# [생성 완료] [803/960] 직장 관계 / 감정 표현 스타일 / 원인·결과문 → 10쌍 추가 (누적 7938쌍)
# [생성 완료] [804/960] 직장 관계 / 감정 표현 스타일 / 명령/요청문 → 10쌍 추가 (누적 7948쌍)
# [생성 완료] [805/960] 직장 관계 / 조언/상담 스타일 / 단문 → 10쌍 추가 (누적 7958쌍)
# [생성 완료] [806/960] 직장 관계 / 조언/상담 스타일 / 복문 → 10쌍 추가 (누적 7968쌍)
# [생성 완료] [807/960] 직장 관계 / 조언/상담 스타일 / 조건문 → 10쌍 추가 (누적 7978쌍)
# [생성 완료] [808/960] 직장 관계 / 조언/상담 스타일 / 비교문 → 10쌍 추가 (누적 7988쌍)
# [생성 완료] [809/960] 직장 관계 / 조언/상담 스타일 / 원인·결과문 → 10쌍 추가 (누적 7998쌍)
# [생성 완료] [810/960] 직장 관계 / 조언/상담 스타일 / 명령/요청문 → 10쌍 추가 (누적 8008쌍)
# [생성 완료] [811/960] 직장 관계 / 고객센터 안내 스타일 / 단문 → 10쌍 추가 (누적 8018쌍)
# [생성 완료] [812/960] 직장 관계 / 고객센터 안내 스타일 / 복문 → 10쌍 추가 (누적 8028쌍)
# [생성 완료] [813/960] 직장 관계 / 고객센터 안내 스타일 / 조건문 → 10쌍 추가 (누적 8038쌍)
# [생성 완료] [814/960] 직장 관계 / 고객센터 안내 스타일 / 비교문 → 10쌍 추가 (누적 8048쌍)
# [생성 완료] [815/960] 직장 관계 / 고객센터 안내 스타일 / 원인·결과문 → 10쌍 추가 (누적 8058쌍)
# [생성 완료] [816/960] 직장 관계 / 고객센터 안내 스타일 / 명령/요청문 → 10쌍 추가 (누적 8068쌍)
# [생성 완료] [817/960] IT/AI / 대화체 / 단문 → 10쌍 추가 (누적 8078쌍)
# [생성 완료] [818/960] IT/AI / 대화체 / 복문 → 10쌍 추가 (누적 8088쌍)
# [생성 완료] [819/960] IT/AI / 대화체 / 조건문 → 10쌍 추가 (누적 8098쌍)
# [생성 완료] [820/960] IT/AI / 대화체 / 비교문 → 10쌍 추가 (누적 8108쌍)
# [생성 완료] [821/960] IT/AI / 대화체 / 원인·결과문 → 10쌍 추가 (누적 8118쌍)
# [생성 완료] [822/960] IT/AI / 대화체 / 명령/요청문 → 10쌍 추가 (누적 8128쌍)
# [생성 완료] [823/960] IT/AI / 문어체(보고서 스타일) / 단문 → 10쌍 추가 (누적 8138쌍)
# [생성 완료] [824/960] IT/AI / 문어체(보고서 스타일) / 복문 → 10쌍 추가 (누적 8148쌍)
# [생성 완료] [825/960] IT/AI / 문어체(보고서 스타일) / 조건문 → 10쌍 추가 (누적 8158쌍)
# [생성 완료] [826/960] IT/AI / 문어체(보고서 스타일) / 비교문 → 10쌍 추가 (누적 8168쌍)
# [생성 완료] [827/960] IT/AI / 문어체(보고서 스타일) / 원인·결과문 → 10쌍 추가 (누적 8178쌍)
# [생성 완료] [828/960] IT/AI / 문어체(보고서 스타일) / 명령/요청문 → 10쌍 추가 (누적 8188쌍)
# [생성 완료] [829/960] IT/AI / SNS 스타일 / 단문 → 10쌍 추가 (누적 8198쌍)
# [생성 완료] [830/960] IT/AI / SNS 스타일 / 복문 → 10쌍 추가 (누적 8208쌍)
# [생성 완료] [831/960] IT/AI / SNS 스타일 / 조건문 → 10쌍 추가 (누적 8218쌍)
# [생성 완료] [832/960] IT/AI / SNS 스타일 / 비교문 → 10쌍 추가 (누적 8228쌍)
# [생성 완료] [833/960] IT/AI / SNS 스타일 / 원인·결과문 → 10쌍 추가 (누적 8238쌍)
# [생성 완료] [834/960] IT/AI / SNS 스타일 / 명령/요청문 → 10쌍 추가 (누적 8248쌍)
# [생성 완료] [835/960] IT/AI / 뉴스 기사체 / 단문 → 10쌍 추가 (누적 8258쌍)
# [생성 완료] [836/960] IT/AI / 뉴스 기사체 / 복문 → 10쌍 추가 (누적 8268쌍)
# [생성 완료] [837/960] IT/AI / 뉴스 기사체 / 조건문 → 10쌍 추가 (누적 8278쌍)
# [생성 완료] [838/960] IT/AI / 뉴스 기사체 / 비교문 → 10쌍 추가 (누적 8288쌍)
# [생성 완료] [839/960] IT/AI / 뉴스 기사체 / 원인·결과문 → 10쌍 추가 (누적 8298쌍)
# [생성 완료] [840/960] IT/AI / 뉴스 기사체 / 명령/요청문 → 10쌍 추가 (누적 8308쌍)
# [생성 완료] [841/960] IT/AI / 기술 설명체 / 단문 → 10쌍 추가 (누적 8318쌍)
# [생성 완료] [842/960] IT/AI / 기술 설명체 / 복문 → 10쌍 추가 (누적 8328쌍)
# [생성 완료] [843/960] IT/AI / 기술 설명체 / 조건문 → 10쌍 추가 (누적 8338쌍)
# [생성 완료] [844/960] IT/AI / 기술 설명체 / 비교문 → 10쌍 추가 (누적 8348쌍)
# [생성 완료] [845/960] IT/AI / 기술 설명체 / 원인·결과문 → 10쌍 추가 (누적 8358쌍)
# [생성 완료] [846/960] IT/AI / 기술 설명체 / 명령/요청문 → 10쌍 추가 (누적 8368쌍)
# [생성 완료] [847/960] IT/AI / 감정 표현 스타일 / 단문 → 10쌍 추가 (누적 8378쌍)
# [생성 완료] [848/960] IT/AI / 감정 표현 스타일 / 복문 → 10쌍 추가 (누적 8388쌍)
# [생성 완료] [849/960] IT/AI / 감정 표현 스타일 / 조건문 → 10쌍 추가 (누적 8398쌍)
# [생성 완료] [850/960] IT/AI / 감정 표현 스타일 / 비교문 → 10쌍 추가 (누적 8408쌍)
# [생성 완료] [851/960] IT/AI / 감정 표현 스타일 / 원인·결과문 → 10쌍 추가 (누적 8418쌍)
# [생성 완료] [852/960] IT/AI / 감정 표현 스타일 / 명령/요청문 → 10쌍 추가 (누적 8428쌍)
# [생성 완료] [853/960] IT/AI / 조언/상담 스타일 / 단문 → 10쌍 추가 (누적 8438쌍)
# [생성 완료] [854/960] IT/AI / 조언/상담 스타일 / 복문 → 10쌍 추가 (누적 8448쌍)
# [생성 완료] [855/960] IT/AI / 조언/상담 스타일 / 조건문 → 10쌍 추가 (누적 8458쌍)
# [생성 완료] [856/960] IT/AI / 조언/상담 스타일 / 비교문 → 10쌍 추가 (누적 8468쌍)
# [생성 완료] [857/960] IT/AI / 조언/상담 스타일 / 원인·결과문 → 10쌍 추가 (누적 8478쌍)
# [생성 완료] [858/960] IT/AI / 조언/상담 스타일 / 명령/요청문 → 10쌍 추가 (누적 8488쌍)
# [생성 완료] [859/960] IT/AI / 고객센터 안내 스타일 / 단문 → 9쌍 추가 (누적 8497쌍)
# [생성 완료] [860/960] IT/AI / 고객센터 안내 스타일 / 복문 → 10쌍 추가 (누적 8507쌍)
# [생성 완료] [861/960] IT/AI / 고객센터 안내 스타일 / 조건문 → 10쌍 추가 (누적 8517쌍)
# [생성 완료] [862/960] IT/AI / 고객센터 안내 스타일 / 비교문 → 10쌍 추가 (누적 8527쌍)
# [생성 완료] [863/960] IT/AI / 고객센터 안내 스타일 / 원인·결과문 → 10쌍 추가 (누적 8537쌍)
# [생성 완료] [864/960] IT/AI / 고객센터 안내 스타일 / 명령/요청문 → 9쌍 추가 (누적 8546쌍)
# [생성 완료] [865/960] 자기계발 / 대화체 / 단문 → 8쌍 추가 (누적 8554쌍)
# [생성 완료] [866/960] 자기계발 / 대화체 / 복문 → 10쌍 추가 (누적 8564쌍)
# [생성 완료] [867/960] 자기계발 / 대화체 / 조건문 → 10쌍 추가 (누적 8574쌍)
# [생성 완료] [868/960] 자기계발 / 대화체 / 비교문 → 10쌍 추가 (누적 8584쌍)
# [생성 완료] [869/960] 자기계발 / 대화체 / 원인·결과문 → 10쌍 추가 (누적 8594쌍)
# [생성 완료] [870/960] 자기계발 / 대화체 / 명령/요청문 → 10쌍 추가 (누적 8604쌍)
# [생성 완료] [871/960] 자기계발 / 문어체(보고서 스타일) / 단문 → 10쌍 추가 (누적 8614쌍)
# [생성 완료] [872/960] 자기계발 / 문어체(보고서 스타일) / 복문 → 10쌍 추가 (누적 8624쌍)
# [생성 완료] [873/960] 자기계발 / 문어체(보고서 스타일) / 조건문 → 10쌍 추가 (누적 8634쌍)
# [생성 완료] [874/960] 자기계발 / 문어체(보고서 스타일) / 비교문 → 10쌍 추가 (누적 8644쌍)
# [생성 완료] [875/960] 자기계발 / 문어체(보고서 스타일) / 원인·결과문 → 10쌍 추가 (누적 8654쌍)
# [생성 완료] [876/960] 자기계발 / 문어체(보고서 스타일) / 명령/요청문 → 10쌍 추가 (누적 8664쌍)
# [생성 완료] [877/960] 자기계발 / SNS 스타일 / 단문 → 9쌍 추가 (누적 8673쌍)
# [생성 완료] [878/960] 자기계발 / SNS 스타일 / 복문 → 10쌍 추가 (누적 8683쌍)
# [생성 완료] [879/960] 자기계발 / SNS 스타일 / 조건문 → 10쌍 추가 (누적 8693쌍)
# [생성 완료] [880/960] 자기계발 / SNS 스타일 / 비교문 → 10쌍 추가 (누적 8703쌍)
# [생성 완료] [881/960] 자기계발 / SNS 스타일 / 원인·결과문 → 10쌍 추가 (누적 8713쌍)
# [생성 완료] [882/960] 자기계발 / SNS 스타일 / 명령/요청문 → 9쌍 추가 (누적 8722쌍)
# [생성 완료] [883/960] 자기계발 / 뉴스 기사체 / 단문 → 10쌍 추가 (누적 8732쌍)
# [생성 완료] [884/960] 자기계발 / 뉴스 기사체 / 복문 → 10쌍 추가 (누적 8742쌍)
# [생성 완료] [885/960] 자기계발 / 뉴스 기사체 / 조건문 → 10쌍 추가 (누적 8752쌍)
# [생성 완료] [886/960] 자기계발 / 뉴스 기사체 / 비교문 → 10쌍 추가 (누적 8762쌍)
# [생성 완료] [887/960] 자기계발 / 뉴스 기사체 / 원인·결과문 → 10쌍 추가 (누적 8772쌍)
# [생성 완료] [888/960] 자기계발 / 뉴스 기사체 / 명령/요청문 → 10쌍 추가 (누적 8782쌍)
# [생성 완료] [889/960] 자기계발 / 기술 설명체 / 단문 → 10쌍 추가 (누적 8792쌍)
# [생성 완료] [890/960] 자기계발 / 기술 설명체 / 복문 → 10쌍 추가 (누적 8802쌍)
# [생성 완료] [891/960] 자기계발 / 기술 설명체 / 조건문 → 10쌍 추가 (누적 8812쌍)
# [생성 완료] [892/960] 자기계발 / 기술 설명체 / 비교문 → 10쌍 추가 (누적 8822쌍)
# [생성 완료] [893/960] 자기계발 / 기술 설명체 / 원인·결과문 → 10쌍 추가 (누적 8832쌍)
# [생성 완료] [894/960] 자기계발 / 기술 설명체 / 명령/요청문 → 9쌍 추가 (누적 8841쌍)
# [생성 완료] [895/960] 자기계발 / 감정 표현 스타일 / 단문 → 8쌍 추가 (누적 8849쌍)
# [생성 완료] [896/960] 자기계발 / 감정 표현 스타일 / 복문 → 10쌍 추가 (누적 8859쌍)
# [생성 완료] [897/960] 자기계발 / 감정 표현 스타일 / 조건문 → 10쌍 추가 (누적 8869쌍)
# [생성 완료] [898/960] 자기계발 / 감정 표현 스타일 / 비교문 → 10쌍 추가 (누적 8879쌍)
# [생성 완료] [899/960] 자기계발 / 감정 표현 스타일 / 원인·결과문 → 10쌍 추가 (누적 8889쌍)
# [생성 완료] [900/960] 자기계발 / 감정 표현 스타일 / 명령/요청문 → 10쌍 추가 (누적 8899쌍)
# [생성 완료] [901/960] 자기계발 / 조언/상담 스타일 / 단문 → 9쌍 추가 (누적 8908쌍)
# [생성 완료] [902/960] 자기계발 / 조언/상담 스타일 / 복문 → 10쌍 추가 (누적 8918쌍)
# [생성 완료] [903/960] 자기계발 / 조언/상담 스타일 / 조건문 → 10쌍 추가 (누적 8928쌍)
# [생성 완료] [904/960] 자기계발 / 조언/상담 스타일 / 비교문 → 10쌍 추가 (누적 8938쌍)
# [생성 완료] [905/960] 자기계발 / 조언/상담 스타일 / 원인·결과문 → 10쌍 추가 (누적 8948쌍)
# [생성 완료] [906/960] 자기계발 / 조언/상담 스타일 / 명령/요청문 → 10쌍 추가 (누적 8958쌍)
# [생성 완료] [907/960] 자기계발 / 고객센터 안내 스타일 / 단문 → 9쌍 추가 (누적 8967쌍)
# [생성 완료] [908/960] 자기계발 / 고객센터 안내 스타일 / 복문 → 10쌍 추가 (누적 8977쌍)
# [생성 완료] [909/960] 자기계발 / 고객센터 안내 스타일 / 조건문 → 10쌍 추가 (누적 8987쌍)
# [생성 완료] [910/960] 자기계발 / 고객센터 안내 스타일 / 비교문 → 10쌍 추가 (누적 8997쌍)
# [생성 완료] [911/960] 자기계발 / 고객센터 안내 스타일 / 원인·결과문 → 10쌍 추가 (누적 9007쌍)
# [생성 완료] [912/960] 자기계발 / 고객센터 안내 스타일 / 명령/요청문 → 9쌍 추가 (누적 9016쌍)
# [생성 완료] [913/960] 사회/뉴스 / 대화체 / 단문 → 10쌍 추가 (누적 9026쌍)
# [생성 완료] [914/960] 사회/뉴스 / 대화체 / 복문 → 10쌍 추가 (누적 9036쌍)
# [생성 완료] [915/960] 사회/뉴스 / 대화체 / 조건문 → 10쌍 추가 (누적 9046쌍)
# [생성 완료] [916/960] 사회/뉴스 / 대화체 / 비교문 → 10쌍 추가 (누적 9056쌍)
# [생성 완료] [917/960] 사회/뉴스 / 대화체 / 원인·결과문 → 10쌍 추가 (누적 9066쌍)
# [생성 완료] [918/960] 사회/뉴스 / 대화체 / 명령/요청문 → 10쌍 추가 (누적 9076쌍)
# [생성 완료] [919/960] 사회/뉴스 / 문어체(보고서 스타일) / 단문 → 10쌍 추가 (누적 9086쌍)
# [생성 완료] [920/960] 사회/뉴스 / 문어체(보고서 스타일) / 복문 → 10쌍 추가 (누적 9096쌍)
# [생성 완료] [921/960] 사회/뉴스 / 문어체(보고서 스타일) / 조건문 → 10쌍 추가 (누적 9106쌍)
# [생성 완료] [922/960] 사회/뉴스 / 문어체(보고서 스타일) / 비교문 → 10쌍 추가 (누적 9116쌍)
# [생성 완료] [923/960] 사회/뉴스 / 문어체(보고서 스타일) / 원인·결과문 → 10쌍 추가 (누적 9126쌍)
# [생성 완료] [924/960] 사회/뉴스 / 문어체(보고서 스타일) / 명령/요청문 → 10쌍 추가 (누적 9136쌍)
# [생성 완료] [925/960] 사회/뉴스 / SNS 스타일 / 단문 → 10쌍 추가 (누적 9146쌍)
# [생성 완료] [926/960] 사회/뉴스 / SNS 스타일 / 복문 → 10쌍 추가 (누적 9156쌍)
# [생성 완료] [927/960] 사회/뉴스 / SNS 스타일 / 조건문 → 10쌍 추가 (누적 9166쌍)
# [생성 완료] [928/960] 사회/뉴스 / SNS 스타일 / 비교문 → 10쌍 추가 (누적 9176쌍)
# [생성 완료] [929/960] 사회/뉴스 / SNS 스타일 / 원인·결과문 → 10쌍 추가 (누적 9186쌍)
# [생성 완료] [930/960] 사회/뉴스 / SNS 스타일 / 명령/요청문 → 10쌍 추가 (누적 9196쌍)
# [생성 완료] [931/960] 사회/뉴스 / 뉴스 기사체 / 단문 → 10쌍 추가 (누적 9206쌍)
# [생성 완료] [932/960] 사회/뉴스 / 뉴스 기사체 / 복문 → 9쌍 추가 (누적 9215쌍)
# [생성 완료] [933/960] 사회/뉴스 / 뉴스 기사체 / 조건문 → 10쌍 추가 (누적 9225쌍)
# [생성 완료] [934/960] 사회/뉴스 / 뉴스 기사체 / 비교문 → 10쌍 추가 (누적 9235쌍)
# [생성 완료] [935/960] 사회/뉴스 / 뉴스 기사체 / 원인·결과문 → 10쌍 추가 (누적 9245쌍)
# [생성 완료] [936/960] 사회/뉴스 / 뉴스 기사체 / 명령/요청문 → 10쌍 추가 (누적 9255쌍)
# [생성 완료] [937/960] 사회/뉴스 / 기술 설명체 / 단문 → 9쌍 추가 (누적 9264쌍)
# [생성 완료] [938/960] 사회/뉴스 / 기술 설명체 / 복문 → 10쌍 추가 (누적 9274쌍)
# [생성 완료] [939/960] 사회/뉴스 / 기술 설명체 / 조건문 → 10쌍 추가 (누적 9284쌍)
# [생성 완료] [940/960] 사회/뉴스 / 기술 설명체 / 비교문 → 10쌍 추가 (누적 9294쌍)
# [생성 완료] [941/960] 사회/뉴스 / 기술 설명체 / 원인·결과문 → 10쌍 추가 (누적 9304쌍)
# [생성 완료] [942/960] 사회/뉴스 / 기술 설명체 / 명령/요청문 → 9쌍 추가 (누적 9313쌍)
# [생성 완료] [943/960] 사회/뉴스 / 감정 표현 스타일 / 단문 → 10쌍 추가 (누적 9323쌍)
# [생성 완료] [944/960] 사회/뉴스 / 감정 표현 스타일 / 복문 → 10쌍 추가 (누적 9333쌍)
# [생성 완료] [945/960] 사회/뉴스 / 감정 표현 스타일 / 조건문 → 10쌍 추가 (누적 9343쌍)
# [생성 완료] [946/960] 사회/뉴스 / 감정 표현 스타일 / 비교문 → 10쌍 추가 (누적 9353쌍)
# [생성 완료] [947/960] 사회/뉴스 / 감정 표현 스타일 / 원인·결과문 → 10쌍 추가 (누적 9363쌍)
# [생성 완료] [948/960] 사회/뉴스 / 감정 표현 스타일 / 명령/요청문 → 10쌍 추가 (누적 9373쌍)
# [생성 완료] [949/960] 사회/뉴스 / 조언/상담 스타일 / 단문 → 10쌍 추가 (누적 9383쌍)
# [생성 완료] [950/960] 사회/뉴스 / 조언/상담 스타일 / 복문 → 10쌍 추가 (누적 9393쌍)
# [생성 완료] [951/960] 사회/뉴스 / 조언/상담 스타일 / 조건문 → 10쌍 추가 (누적 9403쌍)
# [생성 완료] [952/960] 사회/뉴스 / 조언/상담 스타일 / 비교문 → 10쌍 추가 (누적 9413쌍)
# [생성 완료] [953/960] 사회/뉴스 / 조언/상담 스타일 / 원인·결과문 → 10쌍 추가 (누적 9423쌍)
# [생성 완료] [954/960] 사회/뉴스 / 조언/상담 스타일 / 명령/요청문 → 10쌍 추가 (누적 9433쌍)
# [생성 완료] [955/960] 사회/뉴스 / 고객센터 안내 스타일 / 단문 → 10쌍 추가 (누적 9443쌍)
# [생성 완료] [956/960] 사회/뉴스 / 고객센터 안내 스타일 / 복문 → 10쌍 추가 (누적 9453쌍)
# [생성 완료] [957/960] 사회/뉴스 / 고객센터 안내 스타일 / 조건문 → 10쌍 추가 (누적 9463쌍)
# [생성 완료] [958/960] 사회/뉴스 / 고객센터 안내 스타일 / 비교문 → 10쌍 추가 (누적 9473쌍)
# [생성 완료] [959/960] 사회/뉴스 / 고객센터 안내 스타일 / 원인·결과문 → 10쌍 추가 (누적 9483쌍)
# [생성 완료] [960/960] 사회/뉴스 / 고객센터 안내 스타일 / 명령/요청문 → 10쌍 추가 (누적 9493쌍)
#
# [저장 완료] 전체: data/parallel_data_gpt-4o-mini_v2_structured_20251205_160208.csv
# [저장 완료] train: data/parallel_data_gpt-4o-mini_v2_structured_20251205_160208_train.csv
# [저장 완료] valid: data/parallel_data_gpt-4o-mini_v2_structured_20251205_160208_valid.csv
# [저장 완료] test:  data/parallel_data_gpt-4o-mini_v2_structured_20251205_160208_test.csv
